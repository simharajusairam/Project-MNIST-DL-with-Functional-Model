# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Model

# %%
inpt = layers.Input(shape = (28*28,))

# %%
hidden1 = layers.Dense(512, activation = "relu")(inpt)

# %%
hidden2 = layers.Dense(256, activation = "relu")(hidden1)

# %%
out = layers.Dense(2, activation = "softmax")(hidden2)

# %%
m1 = Model(inputs = inpt, outputs = out)

# %%
m1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 514
# ...
# Total params: 533,762
# Trainable params: 533,762
# Non-trainable params: 0
# _________________________________________________________________

# %%
(X_train, y_train), (X_test,y_test) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
y_test.shape
# Out:
# (10000,)

# %%
X_train_scale = X_train/255

# %%
X_test_scale = X_test/255

# %%
X_train_falt = X_train_scale.reshape(-1, 28*28)

# %%
X_test_scale = X_test_scale.reshape(-1, 28*28)

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_train_scale.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
y_test.shape
# Out:
# (10000,)

# %%
inpt = layers.Input(shape = (28,28))

# %%
flat = layers.Flatten()(inpt)

# %%
flat
# Out:
# <KerasTensor: shape=(None, 784) dtype=float32 (created by layer 'flatten')>

# %%
hid1 = layers.Dense(512,activation = "relu")(flat)

# %%
hid2 = layers.Dense(256, activation = "relu")(hid1)

# %%
out = layers.Dense(10, activation = "softmax")(hid2)

# %%
model = Model(inputs = inpt, outputs = out)

# %%
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics="accuracy")

# %%
model.fit(X_train_scale, y_train, epochs=1)
# Out:
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1872 - accuracy: 0.9424

# %%
model.fit(X_train_scale, y_train, epochs=2)
# Out:
# Epoch 1/2
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0797 - accuracy: 0.9750
# Epoch 2/2
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0536 - accuracy: 0.9830
